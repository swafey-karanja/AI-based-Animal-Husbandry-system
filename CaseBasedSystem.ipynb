# %% [markdown]
# # **1.DATA PRE-PROCESSING.**

# %%
import csv

file_path = 'FMD cases.csv'

def preprocess_dataset(file_path):
    """
    Preprocess the dataset by converting it into a dictionary format.

    Args:
        file_path (str): The path to the CSV file containing the dataset.

    Returns:
        dict: A dictionary representing the dataset, where each case is a dictionary containing the input parameters,
              diagnosis, treatment, and outcome.
    """
    case_database = {}

    # Open the CSV file
    with open(file_path, 'r') as file:
        reader = csv.DictReader(file)

        # Iterate over each row (case) in the CSV file
        for row in reader:
            case_id = row['Case ID']
            symptoms = row['Symptoms'].split(', ')  # Split the symptoms into a list
            age = int(row['Animal Age (Months)'])
            sex = row['Animal Sex']
            environmental_conditions = row['Environmental Conditions']
            diagnosis = row['Diagnosis']
            treatment = row['Treatment'].split(', ')  # Split the treatment into a list
            outcome = row['Outcome']

            # Create a dictionary for the current case
            case = {
                'Symptoms': symptoms,
                'Animal Age (Months)': age,
                'Animal Sex': sex,
                'Environmental Conditions': environmental_conditions,
                'Diagnosis': diagnosis,
                'Treatment': treatment,
                'Outcome': outcome
            }

            # Add the case to the case database
            case_database[case_id] = case

    return case_database

# Example usage
case_database = preprocess_dataset(file_path)

print("Case Database:")
print(case_database)

# Print each case individually
print("\nIndividual Cases:")
for case_id, case in case_database.items():
    print(f"\nCase ID: {case_id}")
    for key, value in case.items():
        print(f"{key}: {value}")
# Out:
# Case Database:
# {'CASE001': {'Symptoms': ['Blisters on mouth', 'tongue', 'and feet', 'excessive salivation', 'fever (104Â°F)', 'reduced appetite'], 'Animal Age (Months)': 18, 'Animal Sex': 'Female', 'Environmental Conditions': 'Recent introduction of new cattle', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Recovered'}, 'CASE002': {'Symptoms': ['Blisters on udder', 'fever (103Â°F)', 'decreased milk production', 'lethargy'], 'Animal Age (Months)': 72, 'Animal Sex': 'Female', 'Environmental Conditions': 'Shared grazing pasture with infected herd', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'supportive care'], 'Outcome': 'Recovered with prolonged milk production loss'}, 'CASE003': {'Symptoms': ['Mouth blisters', 'tongue lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge'], 'Animal Age (Months)': 24, 'Animal Sex': 'Male', 'Environmental Conditions': 'Poor biosecurity measures', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Recovered'}, 'CASE004': {'Symptoms': ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed'], 'Animal Age (Months)': 36, 'Animal Sex': 'Female', 'Environmental Conditions': 'Contaminated water source', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Euthanized due to complications'}, 'CASE005': {'Symptoms': ['Udder blisters', 'fever (104Â°F)', 'reduced milk production (>50% drop)', 'weight loss'], 'Animal Age (Months)': 60, 'Animal Sex': 'Female', 'Environmental Conditions': 'Unsanitary milking parlor conditions', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'supportive care'], 'Outcome': 'Recovered with permanent milk production loss'}, 'CASE006': {'Symptoms': ['Mouth blisters', 'excessive salivation', 'fever (103Â°F)', 'decreased rumination'], 'Animal Age (Months)': 48, 'Animal Sex': 'Male', 'Environmental Conditions': 'Introduction of infected livestock', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Recovered'}, 'CASE007': {'Symptoms': ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge', 'reluctance to move'], 'Animal Age (Months)': 30, 'Animal Sex': 'Female', 'Environmental Conditions': 'Overcrowded holding pen during transportation', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Recovered'}, 'CASE008': {'Symptoms': ['Blisters on tongue and gums', 'drooling', 'fever (101Â°F)', 'off-feed'], 'Animal Age (Months)': 36, 'Animal Sex': 'Male', 'Environmental Conditions': 'Shared water trough with infected animals', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'supportive care'], 'Outcome': 'Recovered'}, 'CASE009': {'Symptoms': ['Udder lesions', 'fever (103Â°F)', 'decreased milk yield (>30% drop)', 'weight loss'], 'Animal Age (Months)': 96, 'Animal Sex': 'Female', 'Environmental Conditions': 'Poor hygiene practices during milking', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'supportive care'], 'Outcome': 'Recovered with permanent milk production loss'}, 'CASE010': {'Symptoms': ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'nasal discharge', 'reluctance to eat'], 'Animal Age (Months)': 42, 'Animal Sex': 'Male', 'Environmental Conditions': 'Contact with contaminated equipment', 'Diagnosis': 'Foot-and-Mouth Disease', 'Treatment': ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy'], 'Outcome': 'Recovered'}, 'CASE011': {'Symptoms': ['Blisters on mouth', 'Excessive salivation', 'Fever (104ï¿½F)', 'Lameness'], 'Animal Age (Months)': 30, 'Animal Sex': 'Male', 'Environmental Conditions': 'Overcrowded  ...
#
# Individual Cases:
#
# Case ID: CASE001
# Symptoms: ['Blisters on mouth', 'tongue', 'and feet', 'excessive salivation', 'fever (104Â°F)', 'reduced appetite']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Recent introduction of new cattle
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE002
# Symptoms: ['Blisters on udder', 'fever (103Â°F)', 'decreased milk production', 'lethargy']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with prolonged milk production loss
#
# Case ID: CASE003
# Symptoms: ['Mouth blisters', 'tongue lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE004
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE005
# Symptoms: ['Udder blisters', 'fever (104Â°F)', 'reduced milk production (>50% drop)', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE006
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (103Â°F)', 'decreased rumination']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE007
# Symptoms: ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 30
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE008
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE009
# Symptoms: ['Udder lesions', 'fever (103Â°F)', 'decreased milk yield (>30% drop)', 'weight loss']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE010
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'nasal discharge', 'reluctance to eat']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE011
# Symptoms: ['Blisters on mouth', 'Excessive salivation', 'Fever (104ï¿½F)', 'Lameness']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'Anti-inflammatory drugs', 'Fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE012
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (102Â°F)', 'off-feed']
# Animal Age (Months): 18
# Animal Sex: Male
# Environmental Conditions: Contaminated bedding material
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE013
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (103Â°F)', 'drooling']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE014
# Symptoms: ['Udder lesions', 'fever (101Â°F)', 'decreased milk yield (>20% drop)']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures on the farm
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE015
# Symptoms: ['Foot lesions', 'lameness', 'fever (104Â°F)', 'nasal discharge']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE016
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (102Â°F)', 'off-feed']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE017
# Symptoms: ['Udder blisters', 'fever (103Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE018
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (101Â°F)', 'nasal discharge']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE019
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE020
# Symptoms: ['Blisters on mouth and udder', 'fever (102Â°F)', 'decreased milk yield (>30% drop)']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE021
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'reluctance to eat']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE022
# Symptoms: ['Foot lesions', 'lameness', 'fever (103Â°F)', 'nasal discharge']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE023
# Symptoms: ['Udder blisters', 'fever (102Â°F)', 'decreased milk yield (>25% drop)', 'weight loss']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE024
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE025
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (104Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE026
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE027
# Symptoms: ['Udder lesions', 'fever (103Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE028
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE029
# Symptoms: ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE030
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'decreased rumination']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE031
# Symptoms: ['Udder blisters', 'fever (101Â°F)', 'decreased milk yield (>20% drop)']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE032
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (103Â°F)', 'reluctance to eat']
# Animal Age (Months): 30
# Animal Sex: Female
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE033
# Symptoms: ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Contaminated bedding material
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE034
# Symptoms: ['Udder blisters', 'fever (101Â°F)', 'decreased milk yield (>30% drop)']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE035
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (104Â°F)', 'off-feed']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE036
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE037
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (103Â°F)', 'nasal discharge']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE038
# Symptoms: ['Udder lesions', 'fever (102Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures on the farm
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE039
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE040
# Symptoms: ['Foot lesions', 'lameness', 'fever (104Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE041
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (102Â°F)', 'decreased rumination']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE042
# Symptoms: ['Udder blisters', 'fever (103Â°F)', 'decreased milk yield (>50% drop)']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE043
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE044
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (104Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE045
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE046
# Symptoms: ['Udder lesions', 'fever (101Â°F)', 'decreased milk yield (>20% drop)']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE047
# Symptoms: ['Blisters on mouth and udder', 'fever (103Â°F)', 'decreased milk yield (>40% drop)']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE048
# Symptoms: ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Contaminated bedding material
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE049
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'decreased rumination']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE050
# Symptoms: ['Udder blisters', 'fever (101Â°F)', 'decreased milk yield (>30% drop)', 'weight loss']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE051
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (103Â°F)', 'off-feed']
# Animal Age (Months): 18
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE052
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE053
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE054
# Symptoms: ['Udder lesions', 'fever (104Â°F)', 'decreased milk yield (>50% drop)', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE055
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE056
# Symptoms: ['Foot lesions', 'lameness', 'fever (103Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE057
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (102Â°F)', 'decreased rumination']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE058
# Symptoms: ['Udder blisters', 'fever (101Â°F)', 'decreased milk yield (>40% drop)']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures on the farm
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE059
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (104Â°F)', 'off-feed']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE060
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (103Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE061
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (102Â°F)', 'nasal discharge']
# Animal Age (Months): 18
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE062
# Symptoms: ['Udder lesions', 'fever (103Â°F)', 'decreased milk yield (>30% drop)', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE063
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE064
# Symptoms: ['Foot lesions', 'lameness', 'fever (104Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE065
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (102Â°F)', 'decreased rumination']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE066
# Symptoms: ['Udder blisters', 'fever (105Â°F)', 'decreased milk yield (>50% drop)']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE067
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (103Â°F)', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE068
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (104Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 42
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE069
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (101Â°F)', 'nasal discharge']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE070
# Symptoms: ['Udder lesions', 'fever (102Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE071
# Symptoms: ['Blisters on mouth and udder', 'fever (103Â°F)', 'decreased milk yield (>30% drop)']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE072
# Symptoms: ['Foot lesions', 'lameness', 'fever (101Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 18
# Animal Sex: Male
# Environmental Conditions: Contaminated bedding material
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE073
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'decreased rumination']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE074
# Symptoms: ['Udder blisters', 'fever (102Â°F)', 'decreased milk yield (>20% drop)', 'weight loss']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE075
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (101Â°F)', 'off-feed']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE076
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (103Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE077
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (104Â°F)', 'nasal discharge']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE078
# Symptoms: ['Udder lesions', 'fever (101Â°F)', 'decreased milk yield (>30% drop)', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE079
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (102Â°F)', 'off-feed']
# Animal Age (Months): 42
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE080
# Symptoms: ['Foot lesions', 'lameness', 'fever (103Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE081
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (101Â°F)', 'decreased rumination']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE082
# Symptoms: ['Udder blisters', 'fever (104Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE083
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (102Â°F)', 'off-feed']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE084
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (103Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE085
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (101Â°F)', 'nasal discharge']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE086
# Symptoms: ['Udder lesions', 'fever (105Â°F)', 'decreased milk yield (>50% drop)', 'weight loss']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Poor biosecurity measures on the farm
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE087
# Symptoms: ['Blisters on mouth and tongue', 'excessive salivation', 'fever (103Â°F)', 'off-feed']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Contaminated water source
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE088
# Symptoms: ['Foot lesions', 'lameness', 'fever (102Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 18
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE089
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (104Â°F)', 'decreased rumination']
# Animal Age (Months): 42
# Animal Sex: Female
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE090
# Symptoms: ['Udder blisters', 'fever (101Â°F)', 'decreased milk yield (>30% drop)']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE091
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (103Â°F)', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Poor hygiene practices during milking
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE092
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (102Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE093
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (104Â°F)', 'nasal discharge']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Introduction of new cattle without proper quarantine
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE094
# Symptoms: ['Udder lesions', 'fever (101Â°F)', 'decreased milk yield (>40% drop)', 'weight loss']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Contaminated bedding material
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE095
# Symptoms: ['Blisters on mouth and udder', 'fever (102Â°F)', 'decreased milk yield (>20% drop)']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Shared water trough with infected animals
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE096
# Symptoms: ['Foot lesions', 'lameness', 'fever (103Â°F)', 'nasal discharge', 'reluctance to move']
# Animal Age (Months): 96
# Animal Sex: Male
# Environmental Conditions: Poor biosecurity measures
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE097
# Symptoms: ['Mouth blisters', 'excessive salivation', 'fever (101Â°F)', 'decreased rumination']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Contact with contaminated equipment
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE098
# Symptoms: ['Udder blisters', 'fever (104Â°F)', 'decreased milk yield (>50% drop)', 'weight loss']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor conditions
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered with permanent milk production loss
#
# Case ID: CASE099
# Symptoms: ['Blisters on tongue and gums', 'drooling', 'fever (102Â°F)', 'off-feed']
# Animal Age (Months): 42
# Animal Sex: Male
# Environmental Conditions: Introduction of infected livestock
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE100
# Symptoms: ['Foot lesions', 'severe lameness', 'fever (105Â°F)', 'off-feed', 'dehydration']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Overcrowded holding pen during transportation
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Euthanized due to complications
#
# Case ID: CASE101
# Symptoms: ['Mouth blisters', 'tongue lesions', 'fever (103Â°F)', 'nasal discharge']
# Animal Age (Months): 30
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: Foot-and-Mouth Disease
# Treatment: ['Antibiotics', 'anti-inflammatory drugs', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE102
# Symptoms: ['Hardened udder', 'clots in milk', 'fever (101Â°F)', 'lethargy']
# Animal Age (Months): 30
# Animal Sex: Female
# Environmental Conditions: Recent introduction of new cattle
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cephapirin)', 'fluid therapy']
# Outcome: Recovered
#
# Case ID: CASE103
# Symptoms: ['Hot', 'painful udder', 'fever (104Â°F)', 'reluctance to be milked']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking equipment
# Diagnosis: Mastitis
# Treatment: ['Systemic antibiotics (ceftiofur)', 'pain management']
# Outcome: Recovered with mild scarring
#
# Case ID: CASE104
# Symptoms: ['Abnormal milk (flakes', 'clots)', 'udder warmth', 'off-feed']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: High somatic cell count in bulk tank
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cloxacillin)', 'supportive care']
# Outcome: Recovered with prolonged milk withholding
#
# Case ID: CASE105
# Symptoms: ['Swollen quarter', 'fever (102Â°F)', 'reduced milk yield']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Recent calving
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (amoxicillin)', 'rest']
# Outcome: Recovered with no long-term effects
#
# Case ID: CASE106
# Symptoms: ['Thickened udder secretions', 'udder heat', 'lethargy']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Overcrowded free-stall barn
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (penicillin)', 'anti-inflammatories']
# Outcome: Recovered with some scarring
#
# Case ID: CASE107
# Symptoms: ['Painful udder', 'fever (103Â°F)', 'off-feed', 'weight loss']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Poor ventilation in milking parlor
# Diagnosis: Mastitis
# Treatment: ['Systemic antibiotics (ceftiofur)', 'fluid therapy']
# Outcome: Recovered with no permanent damage
#
# Case ID: CASE108
# Symptoms: ['Clots in milk', 'swollen udder', 'reluctance to move']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: Shared udder washcloths between cows
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (hetacillin)', 'pain management']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE109
# Symptoms: ['Abnormal milk (watery', 'flakes)', 'udder warmth', 'fever (101Â°F)']
# Animal Age (Months): 42
# Animal Sex: Female
# Environmental Conditions: Recent teat injury
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cephapirin)', 'supportive care']
# Outcome: Recovered with prolonged milk withholding
#
# Case ID: CASE110
# Symptoms: ['Swollen', 'painful quarter', 'fever (104Â°F)', 'inappetence']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Poor stall bedding management
# Diagnosis: Mastitis
# Treatment: ['Systemic antibiotics (amoxicillin)', 'anti-inflammatories']
# Outcome: Recovered with no long-term effects
#
# Case ID: CASE111
# Symptoms: ['Swollen quarter', 'abnormal milk (flakes/clots)', 'fever (103Â°F)', 'reduced appetite']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Poor stall hygiene with contaminated bedding
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (pirlimycin)', 'systemic antibiotics (ceftiofur)', 'anti-inflammatory drugs']
# Outcome: Recovered with some residual milk drop
#
# Case ID: CASE112
# Symptoms: ['Hardened udder', 'purulent milk', 'fever (102Â°F)', 'lethargy', 'dehydration']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Recent calving in overcrowded maternity pen
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cephapirin)', 'IV fluids', 'supportive care']
# Outcome: Recovered
#
# Case ID: CASE113
# Symptoms: ['Hot', 'painful udder quarters', 'watery milk', 'fever (104Â°F)', 'inappetence']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Unsanitary milking parlor with poor ventilation
# Diagnosis: Mastitis
# Treatment: ['Systemic antibiotics (ceftiofur)', 'anti-inflammatory drugs', 'udder cold packs']
# Outcome: Recovered with no permanent damage
#
# Case ID: CASE114
# Symptoms: ['Subclinical mastitis - Abnormal milk cell count', 'no systemic signs']
# Animal Age (Months): 96
# Animal Sex: Female
# Environmental Conditions: High bulk tank somatic cell count for herd
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cloxacillin) at dry-off period']
# Outcome: Recovered with no complications
#
# Case ID: CASE115
# Symptoms: ['Unilateral swollen quarter', 'fever (103Â°F)', 'reduced yield', 'off-feed']
# Animal Age (Months): 30
# Animal Sex: Female
# Environmental Conditions: Hot and humid environment with poor ventilation
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (amoxicillin)', 'anti-inflammatories', 'supportive care']
# Outcome: Recovered after extended therapy
#
# Case ID: CASE116
# Symptoms: ['Thickened milk', 'mild udder heat/swelling', 'lethargy']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Overcrowded free-stall barn
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (penicillin) for 3 days']
# Outcome: Recovered with no complications
#
# Case ID: CASE117
# Symptoms: ['Severely swollen', 'hot', 'painful udder', 'toxemia', 'fever (105Â°F)', 'anorexia']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Recent teat injury with contaminated bedding
# Diagnosis: Mastitis
# Treatment: ['Systemic antibiotics (ceftiofur)', 'intramammary treatment', 'IV fluids', 'NSAIDs']
# Outcome: Recovered after intensive therapy
#
# Case ID: CASE118
# Symptoms: ['Abnormal watery milk', 'slight udder firmness', 'no systemic signs']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Shared udder washcloths between cows
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cephapirin) at dry-off', 'proper teat dip protocols']
# Outcome: Recovered after 7days
#
# Case ID: CASE119
# Symptoms: ['Swollen quarter', 'milk clots', 'fever (102Â°F)', 'reduced feed intake']
# Animal Age (Months): 42
# Animal Sex: Female
# Environmental Conditions: Recent growth of environmental mastitis pathogens in bedding
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (hetacillin)', 'systemic anti-inflammatories']
# Outcome: Recovered after 5 days
#
# Case ID: CASE120
# Symptoms: ['Severe udder edema', 'watery/purulent milk', 'toxemia', 'fever (106Â°F)']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Contaminated flooring and high ammonia levels in barn
# Diagnosis: Mastitis
# Treatment: ['Aggressive IV antibiotics', 'fluid therapy', 'anti-inflammatory drugs', 'udder cold packs']
# Outcome: Had to be euthenised due to complications
#
# Case ID: CASE121
# Symptoms: ['Subclinical mastitis - No clinical signs', 'high somatic cell count']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Poor milking hygiene and teat dip practices
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (pirlimycin) at dry-off', 'review milking protocols']
# Outcome: Recovered fully
#
# Case ID: CASE122
# Symptoms: ['Unilateral swollen', 'painful quarter', 'fever (103Â°F)', 'reluctance to move']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Recent teat injury in wet bedding environment
# Diagnosis: Mastitis
# Treatment: ['Intramammary and systemic antibiotics', 'anti-inflammatory drugs', 'stall rest']
# Outcome: Recovered after 7 days of treatment
#
# Case ID: CASE123
# Symptoms: ['Thick', 'clotted milk with flakes', 'firm udder', 'no systemic signs']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Shared water trough between animals
# Diagnosis: Mastitis
# Treatment: ['Intramammary antibiotics (cephapirin) for 5 days']
# Outcome: Recovered with no complications
#
# Case ID: CASE124
# Symptoms: ['Severe udder edema', 'serous milk', 'fever (105Â°F)', 'diarrhea']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Hot and humid climate with poor barn ventilation
# Diagnosis: Mastitis
# Treatment: ['Aggressive IV antibiotics', 'fluid therapy', 'anti-inflammatory drugs', 'supportive care']
# Outcome: Passed away after a few days
#
# Case ID: CASE125
# Symptoms: ['Unilateral quarter firmness', 'abnormal milk', 'no systemic illness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: High somatic cell count on routine screening
# Diagnosis: Mastitis
# ...
# Outcome: Recovered with mild lingering symptoms
#
# Case ID: CASE351
# Symptoms: ['Enlarged lymph nodes', 'weakness', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Shared grazing with buffalo
# Diagnosis: East Coast Fever
# Treatment: ['Symptomatic therapy', 'antiparasitic drugs']
# Outcome: Euthanized due to deteriorating condition
#
# Case ID: CASE352
# Symptoms: ['Labored breathing', 'coughing', 'lethargy']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after intensive treatment
#
# Case ID: CASE353
# Symptoms: ['Diarrhea', 'dehydration', 'reduced appetite']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Inadequate tick control measures
# Diagnosis: East Coast Fever
# Treatment: ['Fluid therapy', 'electrolyte supplementation']
# Outcome: Recovered after supportive care
#
# Case ID: CASE354
# Symptoms: ['Severe fever', 'anorexia', 'weakness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Pasture rotation system
# Diagnosis: East Coast Fever
# Treatment: ['Antipyretics', 'antiparasitic drugs']
# Outcome: Recovered with prolonged convalescence
#
# Case ID: CASE355
# Symptoms: ['Lameness', 'reluctance to move', 'fever']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Grazing near tick-infested wildlife habitats
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with residual lameness
#
# Case ID: CASE356
# Symptoms: ['Anemia', 'pale mucous membranes', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Overcrowded living conditions
# Diagnosis: East Coast Fever
# Treatment: ['Blood transfusion', 'antiparasitic drugs']
# Outcome: Recovered with mild anemia
#
# Case ID: CASE357
# Symptoms: ['Respiratory distress', 'nasal discharge', 'coughing']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent introduction of infected animals
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after aggressive treatment
#
# Case ID: CASE358
# Symptoms: ['Enlarged lymph nodes', 'reduced milk production']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE359
# Symptoms: ['Depression', 'anorexia', 'lethargy']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Culled due to severe symptoms
#
# Case ID: CASE360
# Symptoms: ['Fever', 'nasal discharge', 'anorexia']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with lingering weakness
#
# Case ID: CASE361
# Symptoms: ['Enlarged lymph nodes', 'weakness', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Shared grazing with buffalo
# Diagnosis: East Coast Fever
# Treatment: ['Symptomatic therapy', 'antiparasitic drugs']
# Outcome: Euthanized due to deteriorating condition
#
# Case ID: CASE362
# Symptoms: ['Labored breathing', 'coughing', 'lethargy']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after intensive treatment
#
# Case ID: CASE363
# Symptoms: ['Diarrhea', 'dehydration', 'reduced appetite']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Inadequate tick control measures
# Diagnosis: East Coast Fever
# Treatment: ['Fluid therapy', 'electrolyte supplementation']
# Outcome: Recovered after supportive care
#
# Case ID: CASE364
# Symptoms: ['Severe fever', 'anorexia', 'weakness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Pasture rotation system
# Diagnosis: East Coast Fever
# Treatment: ['Antipyretics', 'antiparasitic drugs']
# Outcome: Recovered with prolonged convalescence
#
# Case ID: CASE365
# Symptoms: ['Lameness', 'reluctance to move', 'fever']
# Animal Age (Months): 24
# Animal Sex: Male
# Environmental Conditions: Grazing near tick-infested wildlife habitats
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with residual lameness
#
# Case ID: CASE366
# Symptoms: ['Anemia', 'pale mucous membranes', 'weight loss']
# Animal Age (Months): 72
# Animal Sex: Female
# Environmental Conditions: Overcrowded living conditions
# Diagnosis: East Coast Fever
# Treatment: ['Blood transfusion', 'antiparasitic drugs']
# Outcome: Recovered with mild anemia
#
# Case ID: CASE367
# Symptoms: ['Respiratory distress', 'nasal discharge', 'coughing']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent introduction of infected animals
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after aggressive treatment
#
# Case ID: CASE368
# Symptoms: ['Enlarged lymph nodes', 'reduced milk production']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE369
# Symptoms: ['Depression', 'anorexia', 'lethargy']
# Animal Age (Months): 36
# Animal Sex: Male
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Culled due to severe symptoms
#
# Case ID: CASE370
# Symptoms: ['Fever', 'nasal discharge', 'anorexia']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with lingering weakness
#
# Case ID: CASE371
# Symptoms: ['Enlarged lymph nodes', 'weakness', 'weight loss']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Shared grazing with buffalo
# Diagnosis: East Coast Fever
# Treatment: ['Symptomatic therapy', 'antiparasitic drugs']
# Outcome: Euthanized due to deteriorating condition
#
# Case ID: CASE372
# Symptoms: ['Labored breathing', 'coughing', 'lethargy']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after intensive treatment
#
# Case ID: CASE373
# Symptoms: ['Diarrhea', 'dehydration', 'reduced appetite']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Inadequate tick control measures
# Diagnosis: East Coast Fever
# Treatment: ['Fluid therapy', 'electrolyte supplementation']
# Outcome: Recovered after supportive care
#
# Case ID: CASE374
# Symptoms: ['Severe fever', 'anorexia', 'weakness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Pasture rotation system
# Diagnosis: East Coast Fever
# Treatment: ['Antipyretics', 'antiparasitic drugs']
# Outcome: Recovered with prolonged convalescence
#
# Case ID: CASE375
# Symptoms: ['Lameness', 'reluctance to move', 'fever']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Grazing near tick-infested wildlife habitats
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with residual lameness
#
# Case ID: CASE376
# Symptoms: ['Anemia', 'pale mucous membranes', 'weight loss']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Overcrowded living conditions
# Diagnosis: East Coast Fever
# Treatment: ['Blood transfusion', 'antiparasitic drugs']
# Outcome: Recovered with mild anemia
#
# Case ID: CASE377
# Symptoms: ['Respiratory distress', 'nasal discharge', 'coughing']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent introduction of infected animals
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after aggressive treatment
#
# Case ID: CASE378
# Symptoms: ['Enlarged lymph nodes', 'reduced milk production']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE379
# Symptoms: ['Depression', 'anorexia', 'lethargy']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Culled due to severe symptoms
#
# Case ID: CASE380
# Symptoms: ['Fever', 'nasal discharge', 'anorexia']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with lingering weakness
#
# Case ID: CASE381
# Symptoms: ['Enlarged lymph nodes', 'weakness', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Shared grazing with buffalo
# Diagnosis: East Coast Fever
# Treatment: ['Symptomatic therapy', 'antiparasitic drugs']
# Outcome: Euthanized due to deteriorating condition
#
# Case ID: CASE382
# Symptoms: ['Labored breathing', 'coughing', 'lethargy']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after intensive treatment
#
# Case ID: CASE383
# Symptoms: ['Diarrhea', 'dehydration', 'reduced appetite']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Inadequate tick control measures
# Diagnosis: East Coast Fever
# Treatment: ['Fluid therapy', 'electrolyte supplementation']
# Outcome: Recovered after supportive care
#
# Case ID: CASE384
# Symptoms: ['Severe fever', 'anorexia', 'weakness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Pasture rotation system
# Diagnosis: East Coast Fever
# Treatment: ['Antipyretics', 'antiparasitic drugs']
# Outcome: Recovered with prolonged convalescence
#
# Case ID: CASE385
# Symptoms: ['Lameness', 'reluctance to move', 'fever']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Grazing near tick-infested wildlife habitats
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with residual lameness
#
# Case ID: CASE386
# Symptoms: ['Anemia', 'pale mucous membranes', 'weight loss']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Overcrowded living conditions
# Diagnosis: East Coast Fever
# Treatment: ['Blood transfusion', 'antiparasitic drugs']
# Outcome: Recovered with mild anemia
#
# Case ID: CASE387
# Symptoms: ['Respiratory distress', 'nasal discharge', 'coughing']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent introduction of infected animals
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after aggressive treatment
#
# Case ID: CASE388
# Symptoms: ['Enlarged lymph nodes', 'reduced milk production']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE389
# Symptoms: ['Depression', 'anorexia', 'lethargy']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Culled due to severe symptoms
#
# Case ID: CASE390
# Symptoms: ['Fever', 'nasal discharge', 'anorexia']
# Animal Age (Months): 48
# Animal Sex: Female
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with lingering weakness
#
# Case ID: CASE391
# Symptoms: ['Enlarged lymph nodes', 'weakness', 'weight loss']
# Animal Age (Months): 60
# Animal Sex: Male
# Environmental Conditions: Shared grazing with buffalo
# Diagnosis: East Coast Fever
# Treatment: ['Symptomatic therapy', 'antiparasitic drugs']
# Outcome: Euthanized due to deteriorating condition
#
# Case ID: CASE392
# Symptoms: ['Labored breathing', 'coughing', 'lethargy']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after intensive treatment
#
# Case ID: CASE393
# Symptoms: ['Diarrhea', 'dehydration', 'reduced appetite']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Inadequate tick control measures
# Diagnosis: East Coast Fever
# Treatment: ['Fluid therapy', 'electrolyte supplementation']
# Outcome: Recovered after supportive care
#
# Case ID: CASE394
# Symptoms: ['Severe fever', 'anorexia', 'weakness']
# Animal Age (Months): 84
# Animal Sex: Female
# Environmental Conditions: Pasture rotation system
# Diagnosis: East Coast Fever
# Treatment: ['Antipyretics', 'antiparasitic drugs']
# Outcome: Recovered with prolonged convalescence
#
# Case ID: CASE395
# Symptoms: ['Lameness', 'reluctance to move', 'fever']
# Animal Age (Months): 48
# Animal Sex: Male
# Environmental Conditions: Grazing near tick-infested wildlife habitats
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with residual lameness
#
# Case ID: CASE396
# Symptoms: ['Anemia', 'pale mucous membranes', 'weight loss']
# Animal Age (Months): 36
# Animal Sex: Female
# Environmental Conditions: Overcrowded living conditions
# Diagnosis: East Coast Fever
# Treatment: ['Blood transfusion', 'antiparasitic drugs']
# Outcome: Recovered with mild anemia
#
# Case ID: CASE397
# Symptoms: ['Respiratory distress', 'nasal discharge', 'coughing']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent introduction of infected animals
# Diagnosis: East Coast Fever
# Treatment: ['Antibiotics', 'anti-inflammatory drugs']
# Outcome: Recovered after aggressive treatment
#
# Case ID: CASE398
# Symptoms: ['Enlarged lymph nodes', 'reduced milk production']
# Animal Age (Months): 72
# Animal Sex: Male
# Environmental Conditions: Shared grazing pasture with infected herd
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Recovered with reduced milk yield
#
# Case ID: CASE399
# Symptoms: ['Depression', 'anorexia', 'lethargy']
# Animal Age (Months): 24
# Animal Sex: Female
# Environmental Conditions: Grazing in tick-infested pastures
# Diagnosis: East Coast Fever
# Treatment: ['Antiparasitic drugs', 'supportive care']
# Outcome: Culled due to severe symptoms
#
# Case ID: CASE400
# Symptoms: ['Fever', 'nasal discharge', 'anorexia']
# Animal Age (Months): 60
# Animal Sex: Female
# Environmental Conditions: Recent exposure to tick-infested areas
# Diagnosis: Foot and Mouth Disease
# Treatment: ['Antibiotics', 'Quarantine', 'Supportive care']
# Outcome: Recovered
#
# Case ID: CASE401
# Symptoms: ['fever', 'mouth lesions', 'lameness']
# Animal Age (Months): 18
# Animal Sex: Female
# Environmental Conditions: Livestock farm, high animal density
# Diagnosis: Foot and Mouth Disease
# Treatment: ['Antibiotics', 'Quarantine', 'Supportive care']
# Outcome: Recovered
#
# Case ID: CASE402
# Symptoms: ['grain-like bumps in the nostrils and inside the lips and cheeks that often develop into ulcers', 'discharge of watery mucus from eyes and nostrils occasionally including blood', 'rapid breathing', 'reduced milk production']
# Animal Age (Months): 62
# Animal Sex: Female
# Environmental Conditions: Recent exposure to pests
# Diagnosis: Unknown
# Treatment: ['Unknown']
# Outcome: Not determined yet

# %% [markdown]
# # **2.CALCULATE SIMILARITY MEASURES.**

# %%
import difflib

def calculate_symptom_similarity(new_symptoms, existing_symptoms):
    """
    Calculate the similarity between the symptoms of a new case and an existing case.

    Args:
        new_symptoms (list): A list of symptoms for the new case.
        existing_symptoms (list): A list of symptoms for an existing case.

    Returns:
        float: A similarity score between 0 and 1, where 1 indicates an exact match.
    """
    new_symptom_set = set(new_symptoms)
    existing_symptom_set = set(existing_symptoms)

    # Calculate the ratio of common symptoms
    common_symptoms = new_symptom_set.intersection(existing_symptom_set)
    symptom_similarity = len(common_symptoms) / max(len(new_symptom_set), len(existing_symptom_set), 1)

    return symptom_similarity

def calculate_age_similarity(new_age, existing_age):
    """
    Calculate the similarity between the ages of a new case and an existing case.

    Args:
        new_age (int): The age (in months) of the new case.
        existing_age (int): The age (in months) of an existing case.

    Returns:
        float: A similarity score between 0 and 1, where 1 indicates an exact match.
    """
    max_age = max(new_age, existing_age)
    age_difference = abs(new_age - existing_age)
    age_similarity = 1 - (age_difference / max_age) if max_age > 0 else 1

    return age_similarity

def calculate_environmental_similarity(new_conditions, existing_conditions):
    """
    Calculate the similarity between the environmental conditions of a new case and an existing case.

    Args:
        new_conditions (str): A string describing the environmental conditions for the new case.
        existing_conditions (str): A string describing the environmental conditions for an existing case.

    Returns:
        float: A similarity score between 0 and 1, where 1 indicates an exact match.
    """
    sequence_matcher = difflib.SequenceMatcher(None, new_conditions, existing_conditions)
    environmental_similarity = sequence_matcher.ratio()

    return environmental_similarity

def calculate_overall_similarity(new_case, existing_case, weights):
    """
    Calculate the overall similarity between a new case and an existing case.

    Args:
        new_case (dict): A dictionary representing the new case.
        existing_case (dict): A dictionary representing an existing case.
        weights (dict): A dictionary containing weights for each feature (symptom, age, environmental conditions).

    Returns:
        float: An overall similarity score between 0 and 1, where 1 indicates an exact match.
    """
    symptom_similarity = calculate_symptom_similarity(new_case.get('Symptoms', []), existing_case.get('Symptoms', []))
    age_similarity = calculate_age_similarity(new_case.get('Animal Age (Months)', 0), existing_case.get('Animal Age (Months)', 0))
    environmental_similarity = calculate_environmental_similarity(new_case.get('Environmental Conditions', ''),
                                                                  existing_case.get('Environmental Conditions', ''))

    overall_similarity = (weights['Symptoms'] * symptom_similarity +
                          weights['Animal Age (Months)'] * age_similarity +
                          weights['Environmental Conditions'] * environmental_similarity)

    return overall_similarity

# %% [markdown]
# # **3. IMPLEMENTING CASE RETRIEVAL**

# %%
from collections import Counter, defaultdict

def retrieve_similar_cases(new_case, case_database, similarity_threshold=0.5, top_n=3):
    """
    Retrieve the most similar cases from the case database for a given new case.

    Args:
        new_case (dict): A dictionary representing the new case.
        case_database (dict): A dictionary containing the existing cases.
        similarity_threshold (float): The minimum similarity score required to consider a case as similar.
        top_n (int): The maximum number of similar cases to retrieve.

    Returns:
        list: A list of tuples, where each tuple contains the case ID, the corresponding case dictionary,
              and the similarity score for the top N most similar cases.
    """
    similar_cases = defaultdict(list)

    # Calculate the similarity between the new case and each existing case
    for case_id, existing_case in case_database.items():
        overall_similarity = calculate_overall_similarity(new_case, existing_case, weights)  # Ensure 'weights' is defined
        if overall_similarity >= similarity_threshold:
            similar_cases[overall_similarity].append((case_id, existing_case, overall_similarity))

    # Sort the similar cases by similarity score in descending order
    sorted_similar_cases = sorted(similar_cases.items(), reverse=True)

    # Retrieve the top N similar cases
    top_similar_cases = []
    for similarity_score, case_list in sorted_similar_cases:
        top_similar_cases.extend(case_list[:top_n])
        top_n -= len(case_list)
        if top_n <= 0:
            break

    return top_similar_cases

# Define the weights dictionary
weights = {
    'Symptoms': 0.6,
    'Animal Age (Months)': 0.2,
    'Environmental Conditions': 0.2
}

# %% [markdown]
# # **4. DETERMINING THE DIAGNOSIS AMND TREATMENT**

# %%
from collections import Counter

def diagnose_and_treat(new_case, similar_cases):
    """
    Determine the diagnosis and treatment for a new case based on the most similar cases.

    Args:
        new_case (dict): A dictionary representing the new case.
        similar_cases (list): A list of tuples, where each tuple contains the case ID, the corresponding case dictionary,
                              and the similarity score for the most similar cases.

    Returns:
        tuple: A tuple containing the determined diagnosis (str) and the recommended treatment (list).
    """
    diagnoses = []
    treatments = []

    # Collect diagnoses and treatments from the similar cases
    for case_id, case, similarity_score in similar_cases:
        diagnoses.append(case['Diagnosis'])
        treatments.append(case['Treatment'])

    # If no similar cases were found, return default values
    if not diagnoses:
        return "Unknown", ["Unknown"]

    # Determine the most common diagnosis
    diagnosis_counter = Counter(diagnoses)
    most_common_diagnosis, _ = diagnosis_counter.most_common(1)[0]

    # Determine the most common treatment
    treatment_counter = Counter([item for sublist in treatments for item in sublist])
    most_common_treatment = [item for item, count in treatment_counter.most_common() if count >= len(similar_cases) // 2]

    return most_common_diagnosis, most_common_treatment

# def retrieve_similar_cases(new_case, case_database, similarity_threshold=0.5, top_n=3):
#     """
#     Retrieve the most similar cases from the case database for a given new case.

#     Args:
#         new_case (dict): A dictionary representing the new case.
#         case_database (dict): A dictionary containing the existing cases.
#         similarity_threshold (float): The minimum similarity score required to consider a case as similar.
#         top_n (int): The maximum number of similar cases to retrieve.

#     Returns:
#         list: A list of tuples, where each tuple contains the case ID, the corresponding case dictionary,
#               and the similarity score for the top N most similar cases.
#     """
#     similar_cases = defaultdict(list)

#     # Calculate the similarity between the new case and each existing case
#     for case_id, existing_case in case_database.items():
#         overall_similarity = calculate_overall_similarity(new_case, existing_case, weights)
#         if overall_similarity >= similarity_threshold:
#             similar_cases[overall_similarity].append((case_id, existing_case, overall_similarity))

#     # Sort the similar cases by similarity score in descending order
#     sorted_similar_cases = sorted(similar_cases.items(), reverse=True)

#     # Retrieve the top N similar cases
#     top_similar_cases = []
#     for similarity_score, case_list in sorted_similar_cases:
#         top_similar_cases.extend(case_list[:top_n])
#         top_n -= len(case_list)
#         if top_n <= 0:
#             break

#     return top_similar_cases

# %% [markdown]
# # **5.PREDICTING THE PROGNOSIS**

# %%
from collections import Counter

def predict_prognosis(new_case, similar_cases):
    """
    Predict the prognosis for a new case based on the outcomes of the most similar cases.

    Args:
        new_case (dict): A dictionary representing the new case.
        similar_cases (list): A list of tuples, where each tuple contains the case ID, the corresponding case dictionary,
                              and the similarity score for the most similar cases.

    Returns:
        str: The predicted prognosis for the new case.
    """
    outcomes = []

    # Collect outcomes from the similar cases
    for case_id, case, similarity_score in similar_cases:
        outcomes.append(case['Outcome'])

    # If no similar cases were found, return a default prognosis
    if not outcomes:
        return "Unable to predict prognosis due to lack of similar cases."

    # Determine the most common outcome
    outcome_counter = Counter(outcomes)
    most_common_outcome, _ = outcome_counter.most_common(1)[0]

    # Determine the prognosis based on the most common outcome
    if "Recovered" in most_common_outcome:
        prognosis = "Likely to recover"
    elif "Euthanized" in most_common_outcome or "Died" in most_common_outcome:
        prognosis = "High risk of complications or mortality"
    else:
        prognosis = "Possible long-term effects or complications"

    return prognosis

# %% [markdown]
# # **6.UPDATING THE CASE BASE**

# %%
import csv
import os
from datetime import datetime
from collections import defaultdict

def update_case_database(case_database, new_case, diagnosis, treatment, outcome, similarity_threshold=0.5):
    """
    Update the case database by adding a new case and its outcome if it's sufficiently dissimilar to existing cases.

    Args:
        case_database (dict): The existing case database.
        new_case (dict): A dictionary representing the new case.
        diagnosis (str): The diagnosed condition for the new case.
        treatment (list): A list of treatments applied for the new case.
        outcome (str): The outcome of the new case.
        similarity_threshold (float): The minimum similarity score required for considering a case similar. Defaults to 0.5.

    Returns:
        dict: The updated case database with the new case added if it meets the similarity threshold.
    """
    # Retrieve similar cases from the case database
    similar_cases = retrieve_similar_cases(new_case, case_database, similarity_threshold=similarity_threshold)

    # If there are no similar cases above the threshold, add the new case
    if not similar_cases:
        # Generate a unique case ID
        num_cases = len(case_database)
        case_id = f"CASE{num_cases + 1:03d}"

        # Add the new case to the database
        new_case_entry = {
        'Case ID': case_id,
        'Symptoms': new_case['Symptoms'],  # Ensure 'symptoms' matches the key used in the new_case dictionary
        'Animal Age (Months)': new_case['Animal Age (Months)'],
        'Animal Sex': new_case['Animal Sex'],
        'Environmental Conditions': new_case['Environmental Conditions'],
        'Diagnosis': diagnosis,
        'Treatment': (treatment),
        'Outcome': outcome
        }
        case_database[case_id] = new_case_entry

    return case_database



def save_case_database(case_database, file_path):
    """
    Save the case database to a CSV file.

    Args:
        case_database (dict): The case database to be saved.
        file_path (str): The path to the CSV file where the database will be saved.
    """
    fieldnames = ['Case ID', 'Symptoms', 'Animal Age (Months)', 'Animal Sex', 'Environmental Conditions', 'Diagnosis', 'Treatment', 'Outcome']

    # Check if the file exists
    file_exists = os.path.isfile(file_path)

    with open(file_path, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)

        # Write header if the file is empty or doesn't exist
        if not file_exists or os.stat(file_path).st_size == 0:
            writer.writeheader()

        # Append data to the file
        for case_id, case in case_database.items():
            writer.writerow({
                'Case ID': case_id,
                'Symptoms': ', '.join(case['Symptoms']),
                'Animal Age (Months)': case['Animal Age (Months)'],
                'Animal Sex': case['Animal Sex'],
                'Environmental Conditions': case['Environmental Conditions'],
                'Diagnosis': case['Diagnosis'],
                'Treatment': ', '.join(case['Treatment']),
                'Outcome': case['Outcome']
            })



def load_case_database(file_path):
    """
    Load the case database from a CSV file.

    Args:
        file_path (str): The path to the CSV file containing the case database.

    Returns:
        dict: A dictionary representing the case database.
    """
    case_database = {}

    try:
        with open(file_path, 'r') as file:
            reader = csv.DictReader(file)
            for row in reader:
                case_id = row['Case ID']
                symptoms = row['Symptoms'].split(', ')
                age = int(row['Animal Age (Months)'])
                sex = row['Animal Sex']
                environmental_conditions = row['Environmental Conditions']
                diagnosis = row['Diagnosis']
                treatment = row['Treatment'].split(', ')
                outcome = row['Outcome']

                case = {
                    'Symptoms': symptoms,
                    'Animal Age (Months)': age,
                    'Animal Sex': sex,
                    'Environmental Conditions': environmental_conditions,
                    'Diagnosis': diagnosis,
                    'Treatment': treatment,
                    'Outcome': outcome
                }

                case_database[case_id] = case
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")

    return case_database

# %% [markdown]
# # **7.UPDATING NEW CASE DATA**

# %%
def fetch_unknown_diagnosis_cases(case_database):
    """
    Fetch cases with an unknown diagnosis from the case database.

    Args:
        case_database (dict): The case database.

    Returns:
        dict: A dictionary containing cases with an unknown diagnosis, where the keys are case IDs and values are case dictionaries.
    """
    unknown_diagnosis_cases = {}
    for case_id, case in case_database.items():
        if case['Diagnosis'] == 'Unknown':
            unknown_diagnosis_cases[case_id] = case
    return unknown_diagnosis_cases

def update_case(case_database, case_id, diagnosis, treatment, outcome):
    """
    Update the diagnosis, treatment, and outcome for a case in the case database.

    Args:
        case_database (dict): The case database.
        case_id (str): The ID of the case to update.
        diagnosis (str): The updated diagnosis for the case.
        treatment (list): A list of treatments for the case.
        outcome (str): The outcome for the case.

    Returns:
        dict: The updated case database.
    """
    case = case_database.get(case_id)
    if case:
        case['Diagnosis'] = diagnosis
        case['Treatment'] = treatment
        case['Outcome'] = outcome
        case_database[case_id] = case
    return case_database

# %%
# # Example usage
# file_path = 'FMD cases.csv'
# case_database = load_case_database(file_path)

# # Fetch cases with an unknown diagnosis
# unknown_diagnosis_cases = fetch_unknown_diagnosis_cases(case_database)
# print(f"Fetched case : {unknown_diagnosis_cases}")

# %%
# # Update the diagnosis, treatment, and outcome for a case
# case_id = 'CASE401'  # Replace with the actual case ID
# diagnosis = 'Foot and Mouth Disease'
# treatment = ['Antibiotics', 'Quarantine', 'Supportive care']
# outcome = 'Recovered'

# case_database = update_case(case_database, case_id, diagnosis, treatment, outcome)

# # Save the updated case database
# save_case_database(case_database, file_path)

# %% [markdown]
# # **8.IMPLEMENTING THE CODE**

# %%
# Define the weights dictionary
weights = {
    'Symptoms': 0.6,
    'Animal Age (Months)': 0.2,
    'Environmental Conditions': 0.2
}

# Example usage
file_path = 'FMD cases.csv'
case_database = load_case_database(file_path)

new_case = {
    'Symptoms': ['fever', 'mouth lesions', 'lameness'],
    'Animal Age (Months)': 18,
    'Animal Sex': 'Female',
    'Environmental Conditions': 'Livestock farm, high animal density'
}

similarity_threshold = 0.5
similar_cases = retrieve_similar_cases(new_case, case_database, similarity_threshold, top_n=3)

if similar_cases:
    diagnosis, treatment = diagnose_and_treat(new_case, similar_cases)
    prognosis = predict_prognosis(new_case, similar_cases)

    # print(f"Similarity_score: {overall_similarity}")
    print(f"Diagnosis: {diagnosis}")
    print(f"Recommended Treatment: {', '.join(treatment)}")
    print(f"Prognosis: {prognosis}")
else:
    # Check if overall similarity score is above the threshold
    overall_similarity = calculate_overall_similarity(new_case, case_database, weights)
    if overall_similarity < similarity_threshold:
        diagnosis, treatment = diagnose_and_treat(new_case, similar_cases)
        outcome = "Not determined yet"
        case_database_updated = update_case_database(case_database, new_case, diagnosis, treatment, outcome, similarity_threshold)
        
        if case_database_updated != case_database:
            print("No update to the case database.")
        else:
            save_case_database(case_database_updated, file_path)
            print("Case database updated with the new case.")
    else:
        print("Similarity score below threshold. New case not added to the database.")

    print("No similar cases found. New case added to the database.")
# Out:
# Diagnosis: Foot and Mouth Disease
# Recommended Treatment: Antibiotics, Quarantine, Supportive care
# Prognosis: Likely to recover

# %%
import sys

def get_user_input():
    """
    Prompt the user for input and return a dictionary representing the new case.
    """
    symptoms = input("Enter the symptoms (comma-separated): ").split(",")
    symptoms = [symptom.strip() for symptom in symptoms]
    animal_age = int(input("Enter the animal age (in months): "))
    animal_sex = input("Enter the animal sex: ")
    environmental_conditions = input("Enter the environmental conditions: ")

    new_case = {
        'Symptoms': symptoms,
        'Animal Age (Months)': animal_age,
        'Animal Sex': animal_sex,
        'Environmental Conditions': environmental_conditions
    }

    return new_case

def main():
    # Define the weights dictionary
    weights = {
        'Symptoms': 0.6,
        'Animal Age (Months)': 0.2,
        'Environmental Conditions': 0.2
    }

    # Example usage
    file_path = 'FMD cases.csv'
    case_database = load_case_database(file_path)

    new_case = get_user_input()

    similarity_threshold = 0.5
    similar_cases = retrieve_similar_cases(new_case, case_database, similarity_threshold, top_n=3)

    if similar_cases:
        diagnosis, treatment = diagnose_and_treat(new_case, similar_cases)
        prognosis = predict_prognosis(new_case, similar_cases)

        print(f"Diagnosis: {diagnosis}")
        print(f"Recommended Treatment: {', '.join(treatment)}")
        print(f"Prognosis: {prognosis}")
    else:
        # Check if overall similarity score is above the threshold
        overall_similarity = calculate_overall_similarity(new_case, case_database, weights)
        if overall_similarity < similarity_threshold:
            diagnosis, treatment = diagnose_and_treat(new_case, similar_cases)
            outcome = "Not determined yet"
            case_database_updated = update_case_database(case_database, new_case, diagnosis, treatment, outcome, similarity_threshold)

            if case_database_updated != case_database:
                print("No update to the case database.")
            else:
                save_case_database(case_database_updated, file_path)
                print("Case database updated with the new case.")
        else:
            print("Similarity score below threshold. New case not added to the database.")

        print("No similar cases found. New case added to the database.")

if __name__ == "__main__":
    main()
# Out:
# Diagnosis: East Coast Fever
# Recommended Treatment: Antiparasitic drugs, supportive care
# Prognosis: Possible long-term effects or complications
